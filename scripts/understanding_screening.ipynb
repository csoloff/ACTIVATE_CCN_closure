# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv('../tables/merged_final_non_org_fixed.csv', parse_dates=['Time_Mid'])

# %%
d = pd.read_csv('../tables/merged_observed_fixed.csv', parse_dates=['Time_Mid'])

# %%
merged = d[np.logical_not((d['ams_tot'] <= 0.04) | (d['N_CCN_stdPT'] <= 50))].reset_index(drop=True)

# %%
merged[merged['Time_Mid'].dt.month ==9]
# Out:
#       Unnamed: 0  index                Time_Mid  SMPS_Bin02  SMPS_Bin03  \
# 3427        4602   4602 2020-09-02 15:54:17.500        0.00        0.00
# 3428        4603   4603 2020-09-02 15:55:17.500        0.00        0.00
# 3429        4604   4604 2020-09-02 15:56:17.500        0.00        0.00
# 3430        4605   4605 2020-09-02 15:57:17.500        0.00        0.00
# 3431        4606   4606 2020-09-02 15:58:17.500        0.00        0.00
# ...          ...    ...                     ...         ...         ...
# 4827        6433   6433 2020-09-30 19:27:03.500     3141.51        0.00
# 4828        6434   6434 2020-09-30 19:28:03.500        0.00        0.00
# 4829        6435   6435 2020-09-30 19:29:03.500        0.00        0.00
# 4830        6436   6436 2020-09-30 19:30:03.500     2462.30     2639.46
# 4831        6437   6437 2020-09-30 19:31:03.500        0.00        0.00
#
#       SMPS_Bin04  SMPS_Bin05  SMPS_Bin06  SMPS_Bin07  SMPS_Bin08  ...  \
# ...

# %%
d
# Out:
#        Unnamed: 0  index                Time_Mid  SMPS_Bin02  SMPS_Bin03  \
# 0               0      0 2020-02-14 17:02:30.500         NaN         NaN
# 1               1      1 2020-02-14 17:03:30.500         NaN         NaN
# 2               2      2 2020-02-14 17:04:30.500         NaN         NaN
# 3               3      3 2020-02-14 17:05:30.500         NaN         NaN
# 4               4      4 2020-02-14 17:06:30.500         NaN         NaN
# ...           ...    ...                     ...         ...         ...
# 26602       26602  26602 2022-06-18 15:11:01.500         0.0         0.0
# 26603       26603  26603 2022-06-18 15:12:01.500         0.0         0.0
# 26604       26604  26604 2022-06-18 15:13:01.500         0.0         0.0
# 26605       26605  26605 2022-06-18 15:14:01.500         0.0         0.0
# 26606       26606  26606 2022-06-18 15:15:01.500         0.0         0.0
#
#        SMPS_Bin04  SMPS_Bin05  SMPS_Bin06  SMPS_Bin07  SMPS_Bin08  ...  \
# ...

# %%
ds
# Out:
#        Unnamed: 0.1  level_0  Unnamed: 0  index                Time_Mid  \
# 0                 0        0           0      0 2020-02-14 17:02:30.500
# 1                 1        1           1      1 2020-02-14 17:03:30.500
# 2                 2        2           2      2 2020-02-14 17:04:30.500
# 3                 3        3           3      3 2020-02-14 17:05:30.500
# 4                 4        4           4      4 2020-02-14 17:06:30.500
# ...             ...      ...         ...    ...                     ...
# 13665         13665    16801       26602  26602 2022-06-18 15:11:01.500
# 13666         13666    16802       26603  26603 2022-06-18 15:12:01.500
# 13667         13667    16803       26604  26604 2022-06-18 15:13:01.500
# 13668         13668    16804       26605  26605 2022-06-18 15:14:01.500
# 13669         13669    16805       26606  26606 2022-06-18 15:15:01.500
#
#        SMPS_Bin02  SMPS_Bin03  SMPS_Bin04  SMPS_Bin05  SMPS_Bin06  ...  \
# ...
